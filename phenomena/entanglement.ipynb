# %%
from qiskit import QuantumCircuit, Aer, execute
from qiskit.visualization import plot_histogram, plot_state_qsphere
qasm_backend = Aer.get_backend("qasm_simulator")
statevector_backend = Aer.get_backend("statevector_simulator")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-396b4df02bf8> in <module>
#       6 import qiskit
#       7
# ----> 8 qiskit.IBMQ("457ea5a67b0b5a6ea7ec890f7860de37f667a01509230bce408978507dd6357930aa3fa5d6c48e1e1b3830f700cbfc460bc0e69f0a14c864f2fadf55dd7c1b32")
#
# TypeError: 'IBMQFactory' object is not callable

# %%
qc = QuantumCircuit(2)

qc.h(0)
qc.cx(0, 1)

state_vector = execute(qc, statevector_backend).result().get_statevector()
plot_state_qsphere(state_vector)

# %%
qc.measure_all()
qc.draw(output="mpl")

# %%
counts = execute(qc, qasm_backend).result().get_counts()
plot_histogram(counts)
